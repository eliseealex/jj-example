# %%
# !jj git init --colocate
# Out:
# Done importing changes from the underlying Git repo.
# Hint: The following remote bookmarks aren't associated with the existing local bookmarks:
#   main@origin
# Hint: Run the following command to keep local bookmarks updated on future pulls:
#   jj bookmark track main@origin
# Initialized repo in "."

# %%
# Change id is rtzyuqqx -> it will stay the same, and abstract away commits
# !jj status
# Out:
# The working copy has no changes.
# Working copy  (@) : kvzulytt 3c7af22d (empty) (no description set)
# Parent commit (@-): rotlyxnl ee85fee6 main main@origin | first commit

# %%
# !jj describe -m "Demo Change"
# Out:
# Working copy  (@) now at: rtzyuqqx 4614ab87 Demo Change
# Parent commit (@-)      : rotlyxnl ee85fee6 main main@origin | first commit
# ...
# Hint: To configure, run:
#   jj config set --user user.name "Some One"
#   jj config set --user user.email "someone@example.com"

# %%
# !echo "# test" > TEST.MD
